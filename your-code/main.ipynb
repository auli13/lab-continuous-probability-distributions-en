# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
# your code here
data = np.random.uniform(10,50, 1000) # low, high, count

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
def generate_uniform(bottom, ceiling, count):
    return np.random.uniform(low=bottom, high=ceiling, size=count)

# %%
# your code here
data_u_1 = generate_uniform(10,15, 100)
data_u_2 = generate_uniform(10,60, 1000)

# %%
# your code here
fig, axes = plt.subplots(1, 2, figsize=(10, 6),sharey=True)

axes[0].hist(data_u_1, bins=10, edgecolor='black', color='blue', alpha=0.7)
axes[0].set_title('Uniform Distribution\n(bottom=10, ceiling=15, count=100)')
axes[0].set_xlabel('Value')
axes[0].set_ylabel('Count')

axes[1].hist(data_u_2, bins=10, edgecolor='black', color='blue', alpha=0.7)
axes[1].set_title('Uniform Distribution\n(bottom=10, ceiling=60, count=1,000)')
axes[1].set_xlabel('Value')
axes[1].set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
#Dataset 2 is visually more stable and flat because, being a larger sample, the randomness stabilizes.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
# your code here
def generate_normal(mean,std,count):
    return (norm.rvs(loc=mean, scale = std, size = count))

# %%
# your code here
data_n_1 = generate_normal(10,1, 1000)
data_n_2 = generate_normal(10,50, 1000)

# %%
# your code here
fig, axes = plt.subplots(1, 2, figsize=(10, 6),sharey=True)

axes[0].hist(data_n_1, bins=100, edgecolor='black', color='blue', alpha=0.7)
axes[0].set_title('Normal Distribution\n(mean=10, std=1, count=1,000)')
axes[0].set_xlabel('Value')
axes[0].set_ylabel('Count')


axes[1].hist(data_n_2, bins=100, edgecolor='black', color='blue', alpha=0.7)
axes[1].set_title('Normal Distribution\n(mean=10, std=50, count=1,000)')
axes[1].set_xlabel('Value')
axes[1].set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# Your answer here
# #Second Dataset has a higher standard deviation, the dispersion of the values are greater.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
# your code here
vehicles = pd.read_csv("vehicles.csv")
vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# your code here
plt.figure(figsize=(10, 4))
sns.histplot(vehicles["Fuel Barrels/Year"])
plt.tight_layout()
plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
plt.figure(figsize=(10, 4))
sns.histplot(vehicles["CO2 Emission Grams/Mile"])
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
# your code here 
plt.figure(figsize=(10, 4))
sns.histplot(vehicles["Combined MPG"])
plt.tight_layout()
plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
#We can evaluate how close the variables are to a normal distribution by checking their mean , std and median. 
#If they are close to each other, the distribution is likely to be normal. We can also check the skewness and kurtosis of the distribution.
#If Skewness and Kurtosis values are close to zero, the distribution is likely to be normal.

# %%
# your code here
vehicles["Fuel Barrels/Year"].describe()
# Out:
# count    35952.000000
# mean        17.609056
# std          4.467283
# min          0.060000
# 25%         14.699423
# 50%         17.347895
# 75%         20.600625
# max         47.087143
# Name: Fuel Barrels/Year, dtype: float64

# %%
print("Skewness:", vehicles["Fuel Barrels/Year"].skew())
print("Kurtosis:", vehicles["Fuel Barrels/Year"].kurt())
# Out:
# Skewness: 0.6382712089398944
# Kurtosis: 1.4682848792454157

# %%
# your code here
vehicles["CO2 Emission Grams/Mile"].describe()
# Out:
# count    35952.000000
# mean       475.316339
# std        119.060773
# min         37.000000
# 25%        395.000000
# 50%        467.736842
# 75%        555.437500
# max       1269.571429
# Name: CO2 Emission Grams/Mile, dtype: float64

# %%
print("Skewness:", vehicles["CO2 Emission Grams/Mile"].skew())
print("Kurtosis:", vehicles["CO2 Emission Grams/Mile"].kurt())
# Out:
# Skewness: 0.7416918391899279
# Kurtosis: 1.26358279847308

# %%
# your code here
vehicles["Combined MPG"].describe()
# Out:
# count    35952.000000
# mean        19.929322
# std          5.112409
# min          7.000000
# 25%         16.000000
# 50%         19.000000
# 75%         23.000000
# max         56.000000
# Name: Combined MPG, dtype: float64

# %%
print("Skewness:", vehicles["Combined MPG"].skew())
print("Kurtosis:", vehicles["Combined MPG"].kurt())
# Out:
# Skewness: 1.067772701547105
# Kurtosis: 2.7225513349006327

# %% [markdown]
# None of them are normally ditributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
def generate_expo(size, mean=10):
    return np.random.exponential(scale=mean, size=size)

data_e_1 = generate_expo(10,10)
data_e_2 = generate_expo(100,10)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 6),sharey=True)

axes[0].hist(data_e_1, bins=100, edgecolor='black', color='blue', alpha=0.7)
axes[0].set_title('Exponential Distribution\n(mean=10, size=10)')
axes[0].set_xlabel('Value')
axes[0].set_ylabel('Count')


axes[1].hist(data_e_2, bins=100, edgecolor='black', color='blue', alpha=0.7)
axes[1].set_title('Exponential Distribution\n(mean=10, size=100)')
axes[1].set_xlabel('Value')
axes[1].set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The mean changes, so the distribution changes as well.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your code here
mean = 10
t = 15

prob = 1 - np.exp(-1/mean * t)
print(f"Probability that a customer will spend less than fifteen minutes in the bank: {prob:.4f}")
# Out:
# Probability that a customer will spend less than fifteen minutes in the bank: 0.7769

# %%
# your answer here
# Hint: This is same as saying P(x<15)

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your code here

print(f"Probability that the customer will spend more than 15 minutes: {1-prob:.4f}")
# Out:
# Probability that the customer will spend more than 15 minutes: 0.2231
